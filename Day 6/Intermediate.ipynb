# %% [markdown]
# 4

# %% [markdown]
# ![Capture_1789039737557.JPG](./Capture_1789039737557.JPG "Capture_1789039737557.JPG")

# %% [markdown]
# - Bronze:
# Primary consumers: Data Engineers
# Contains raw ingested data without transformations or cleaning
#
# - Silver:
# Primary consumers: Data Analysts
# Bronze tables are transformed into cleaned data by handling nulls, duplicates, data type etc and stored to silver
#
# - Gold:
# Primary consumers: Executives
# Conatins business ready tables, aggregations and KPIs, used for reporting and dashboard

# %% [markdown]
# 5

# %% [markdown]
# ![Capture1_1789039765279.JPG](./Capture1_1789039765279.JPG "Capture1_1789039765279.JPG")

# %% [markdown]
# - Lakeflow designer interface visual approach was faster for simple transformations such as filtering, selection columns and handling missing values
# - It is more user freindly to understand visually for users with less coding experience. But writing tranformation code gives more flexiblity and control for complex tranformations and logics

# %% [markdown]
# 6

# %% [markdown]
# ![Capture_1789040063853.JPG](./Capture_1789040063853.JPG "Capture_1789040063853.JPG")

# %% [markdown]
# The lakeflow job which run on schedule from bronze raw data to silver transformed data to finally business ready kpis

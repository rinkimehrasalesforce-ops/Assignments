# %%
# %sql
create table if not exists cyntexa_dev.sales.sales_bronze

# %%
spark.sql(f"""
copy into cyntexa_dev.sales.sales_bronze
from (
    select *,
           _metadata.file_name as source_file_name,
           _metadata.file_path as source_file_path,
           current_timestamp() as ingested_at
    from '/Volumes/cyntexa_dev/sales/raw/sales1.csv'
)
fileformat = csv
format_options ('header' = 'true')
copy_options ('mergeSchema' = 'true');          
""")

# %%
# %sql
create or replace view cyntexa_dev.sales.gold_total_revenue as
select customer_id, sum(total_amount) as total_revenue from cyntexa_dev.sales.sales_cleaned
group by customer_id order by sum(total_amount)

# %%
# %sql
select * from cyntexa_dev.sales.gold_total_revenue
